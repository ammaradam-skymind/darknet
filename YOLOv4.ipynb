# %% [markdown]
# <a href="https://colab.research.google.com/github/ammaradam-skymind/darknet/blob/master/YOLOv4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # YOLOv4 for Custom Dataset
#
# Reference: [Link](https://medium.com/analytics-vidhya/implementing-yolov4-to-detect-custom-objects-using-google-colab-6691c98b15ff)

# %% [markdown]
# ![Comparison of YOLOv4 to SOTA object detectors](https://miro.medium.com/max/1400/1*yLe9jJTMmdYPT_TZSDdb-w.jpeg)

# %% [markdown]
# ## Environment Setup

# %% [markdown]
# ### Check GPU
# - Often include Nvidia K80s, T4s, P4s and P100s

# %%
# !nvidia-smi
# Out:
# Fri Jun  5 09:17:59 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8    25W / 149W |      0MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Check CUDA version
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %% [markdown]
# ### To avoid DISCONNECT in Google Colab:
# - Press `Ctrl + Shift + i` in browser to open console
# - In console, paste following code:
# ```
# function ClickConnect(){
# console.log("Working");
# document.querySelector("colab-toolbar-button#connect").click()
# }setInterval(ClickConnect,60000)
# ```

# %% [markdown]
# ### Import libraries

# %%
import os
import random
import xml.etree.ElementTree as ET
import cv2
import matplotlib.pyplot as plt

# %matplotlib inline
# !rm -fr darknet

# %% [markdown]
# ## Darknet Build
# - Using open-source neural network framework Darknet
# - Download and install

# %%
# !git clone https://github.com/AlexeyAB/darknet/
# !git clone https://github.com/ammaradam-skymind/darknet/
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 13576, done.
# remote: Total 13576 (delta 0), reused 0 (delta 0), pack-reused 13576
# Receiving objects: 100% (13576/13576), 12.22 MiB | 17.35 MiB/s, done.
# Resolving deltas: 100% (9257/9257), done.

# %% [markdown]
# ### Installation
# - Set GPU, CUDNN, OPENCV to 1

# %%
% cd darknet
# Out:
# /content/darknet

# %%
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/g' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/g' Makefile
# !apt update
# !apt-get install libopencv-dev

# %% [markdown]
# ### Compile & configure
# - Compile project after editing Makefile
# - Download pre-trained weights of YOLOv4

# %%
# !make &> compile.log

# %%
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights

# %%
def predictImage(imageDir):
  os.system("cd /content/darknet && ./darknet detect cfg/yolov4.cfg yolov4.weights {}".format(imageDir))
  image = cv2.imread("/content/darknet/predictions.jpg")
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)
  fig = plt.gcf()
  fig.set_size_inches(15, 8)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %%
predictImage("data/person.jpg")

# %% [markdown]
# ## Configurations
# - Based on your requirement select a YOLOv4 config file. I selected yolov4-custom.cfg, copy the contents of cfg/yolov4-custom.cfg to a new file cfg/yolo-obj.cfg. Adjust the parameters like batch, subdivisions, steps, max_batches accordingly. For more info on parameters refer to this [link](https://github.com/AlexeyAB/darknet/wiki/CFG-Parameters-in-the-%5Bnet%5D-section).
#
# - **Tip:**
# Set max_batches value a minimum of 2000 classes and steps to 80% - 90% of max_batches. Also the width, height parameters should be a multiple of 32 (I have used 416x416).
#
# - Update the classes parameter to the number of objects in the 3 yolo layers in the yolo-obj.cfg file in lines 970, 1058, 1146 to 2, since we have only 2 classes (mask, no_mask). Now similarly, update the filters parameter to filters=(classes + 5) x 3 in the 3 convolutional layers before each yolo layer. In this case classes = 2 so, set the filters to 21 in the lines 963, 1051, 1139 (Don’t write filters = (classes + 5) x 3 in the .cfg file)

# %%
% cd '/content/darknet/build/darknet/x64/cfg'

# !cp 'yolov4-custom.cfg' 'yolo-obj.cfg'

# !sed -i 's/batch=64/batch=64/g' yolo-obj.cfg
# !sed -i 's/subdivisions=16/subdivisions=8/g' yolo-obj.cfg     #8
# !sed -i 's/width=608/width=160/g' yolo-obj.cfg
# !sed -i 's/height=608/height=160/g' yolo-obj.cfg
# !sed -i 's/width=608/width=256/g' yolo-obj.cfg
# !sed -i 's/height=608/height=256/g' yolo-obj.cfg

# !sed -i 's/max_batches = 500500/max_batches = 6000/g' yolo-obj.cfg
# !sed -i 's/max_batches = 500500/max_batches = 20000/g' yolo-obj.cfg
# !sed -i 's/steps=400000,450000/steps=4800,5400/g' yolo-obj.cfg
# !sed -i 's/steps=400000,450000/steps=16000,18000/g' yolo-obj.cfg

# !sed -i 's/classes=80/classes=3/g' yolo-obj.cfg
# !sed -i 's/filters=255/filters=24/g' yolo-obj.cfg     # (no of class + 5) * 3
# Out:
# /content/darknet/build/darknet/x64/cfg

# %% [markdown]
# -  Create `obj.names` in the directory `build\darknet\x64\data\` with class names
# - Create *train.txt* and *test.txt* files in the directory `build\darknet\x64\data\` using following code:

# %%
obj_class = [
             'dueDate', 
             'invDate', 
             'invNo', 
            #  'item', 
            #  'itemDesc', 
            #  'itemQty', 
            #  'suppAddr', 
            #  'suppName', 
            #  'totalPrice', 
            #  'unitPrice'
            ]

# %%
% cd '/content/darknet/build/darknet/x64/data/'

with open('obj.names', 'w') as f:
    for item in obj_class:
        f.write("%s\n" % item)
# Out:
# /content/darknet/build/darknet/x64/data

# %%
DATASET_DRIVEID = '1mr0WFbBUQLW3cpSMK-3-tLrYbEcCA5eV'   # training images
DATASET_DIR = '/content/darknet/build/darknet/x64/data/obj'
DATASET_ZIP_DIR = '/content/darknet/build/darknet/x64/data'

# %%
from google.colab import drive
from google.colab import files
import shutil

DRIVE_DATASET = '/content/gdrive/My Drive/OCR Object Detection/obj.zip'

drive.mount('/content/gdrive')
shutil.copy(DRIVE_DATASET, DATASET_ZIP_DIR + '/obj.zip')
print('Download completed!')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# Download completed!

# %%
import zipfile

file_name = DATASET_ZIP_DIR + '/obj.zip'

os.makedirs(DATASET_ZIP_DIR, exist_ok=True)
with zipfile.ZipFile(file_name, 'r') as zip_ref:
  zip_ref.extractall(DATASET_ZIP_DIR)
os.remove(file_name)
print('Extract completed!')
# Out:
# Extract completed!

# %%
for xml_file in [f for f in os.listdir(DATASET_DIR) if f.endswith(".xml")]:
  tree = ET.parse(os.path.join(DATASET_DIR, xml_file))
  root = tree.getroot()

  obj_list = []

  for elem in root:

    if elem.tag == 'size':
      for subelem in elem:
        if subelem.tag == 'width':
          img_width = subelem.text
        if subelem.tag == 'height':
          img_height = subelem.text

    if elem.tag == 'object':
      obj_name = None
      obj_classId = None
      for subelem in elem:
        if subelem.tag == 'name':
          # ONLY IF TRAINING SPECIFIC CLASSES
          if subelem.text == 'dueDate' or subelem.text == 'invDate' or subelem.text == 'invNo':
            obj_name = subelem.text
            obj_classId = obj_class.index(obj_name)
        if subelem.tag == 'bndbox':
          for subsubelem in subelem:
            if subsubelem.tag == 'xmin':
              xmin = float("{:.6f}".format(int(subsubelem.text)/int(img_width)))
            if subsubelem.tag == 'xmax':
              xmax = float("{:.6f}".format(int(subsubelem.text)/int(img_width)))
            if subsubelem.tag == 'ymin':
              ymin = float("{:.6f}".format(int(subsubelem.text)/int(img_height)))
            if subsubelem.tag == 'ymax':
              ymax = float("{:.6f}".format(int(subsubelem.text)/int(img_height)))
      
      if obj_classId is not None:
        obj_elem = "{} {} {} {} {}".format(obj_classId, xmin, ymin, xmax, ymax)
        obj_list.append(obj_elem)
  
  text_file = xml_file.replace(".xml", ".txt")

  # print(text_file)
  # print(obj_list)
  # print('\n'.join(obj_list))

  f=open(os.path.join(DATASET_DIR, text_file),'w')
  s1='\n'.join(obj_list)
  f.write(s1)
  f.close()

# %%
# Replace with path to your images
path = '/content/darknet/build/darknet/x64/data/obj/'

images = []
for i in [f for f in os.listdir(path) if f.endswith(".jpg")]:
    temp = path+i
    images.append(temp)
    # print(temp)

# train and test split... adjust it if necessary
trainlen = round(len(images)*.80)
testlen = round(len(images)*.10)
validlen = round(len(images)*.10)

print("-- Dataset Size --\n Total: {}\n Train: {}\n Test: {}\n Validate: {}".format(trainlen + testlen, trainlen, testlen, validlen))

random.shuffle(images)
valid = images[:validlen]
test = images[validlen:validlen+testlen]
train = images[validlen+testlen:]

text_path = '/content/darknet/build/darknet/x64/data/'

with open(text_path + 'train.txt', 'w') as f:
    for item in train:
        f.write("%s\n" % item)

with open(text_path + 'test.txt', 'w') as f:
    for item in test:
        f.write("%s\n" % item)

with open(text_path + 'valid.txt', 'w') as f:
    for item in valid:
        f.write("%s\n" % item)
# Out:
# -- Dataset Size --
#  Total: 521
#  Train: 463
#  Test: 58
#  Validate: 58

# %% [markdown]
# - Put all the image files(.jpg) and label files(.txt) in the same directory: `build\darknet\x64\data\obj`
# - Make `obj.data` file in directory `build\darknet\x64\data\` which should contain below: (edit where necessary)
# ```
# classes= 10
# train = build/darknet/x64/data/train.txt
# valid = build/darknet/x64/data/test.txt
# names = build/darknet/x64/data/obj.names
# backup = build/darknet/x64/backup/
# ```
# - Then, download pre-trained weights for convolutional layers [here](https://drive.google.com/open?id=1JKF-bdIklxOOVy-2Cr5qdvjgGpmGfcbp) (depends on configuration used)
# - Put in `build\darknet\x64`

# %%
% cd '/content/darknet/build/darknet/x64/data/'

with open('obj.data', 'w') as f:
  f.write("%s\n" % 'classes= 3')
  # f.write("%s\n" % 'classes= 10')
  f.write("%s\n" % 'train = build/darknet/x64/data/train.txt')
  f.write("%s\n" % 'valid = build/darknet/x64/data/test.txt')
  f.write("%s\n" % 'names = build/darknet/x64/data/obj.names')
  f.write("%s" % 'backup = build/darknet/x64/backup/')
# Out:
# /content/darknet/build/darknet/x64/data

# %%
# % cd '/content/darknet/build/darknet/x64'

# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.conv.137

# %%
DRIVE_WEIGHTS = '/content/gdrive/My Drive/HLA/Models/YOLOv4/Exp1/yolov4-obj_best_61.weights'
COLAB_WEIGHTS = '/content/darknet/build/darknet/x64/yolov4-obj_best_61.weights'

# drive.mount('/content/gdrive')
shutil.copy(DRIVE_WEIGHTS, COLAB_WEIGHTS)
print('Download completed!')
# Out:
# Download completed!

# %% [markdown]
# ## Training

# %%
% cd '/content/darknet'

# !./darknet detector train build/darknet/x64/data/obj.data build/darknet/x64/cfg/yolo-obj.cfg build/darknet/x64/yolov4.conv.137 -dont_show
# !./darknet detector train build/darknet/x64/data/obj.data build/darknet/x64/cfg/yolo-obj.cfg build/darknet/x64/yolov4-obj_best_61.weights -map -dont_show -clear
# Out:
# Streaming output truncated to the last 5000 lines.
#  1248: 2.424006, 1.853055 avg loss, 0.001000 rate, 4.842057 seconds, 79872 images, 11.847959 hours left
# Loaded: 4.247679 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1249: 2.466992, 1.914449 avg loss, 0.001000 rate, 4.686728 seconds, 79936 images, 11.838820 hours left
# Loaded: 2.823162 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1250: 1.856129, 1.908617 avg loss, 0.001000 rate, 4.687592 seconds, 80000 images, 11.838341 hours left
# Resizing, random_coef = 1.40
#
#  320 x 320
#  try to allocate additional workspace_size = 29.49 MB
#  CUDA allocate done!
# Loaded: 5.404824 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1251: 2.353451, 1.953100 avg loss, 0.001000 rate, 6.951802 seconds, 80064 images, 11.819058 hours left
# Loaded: 2.660723 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1252: 2.149122, 1.972703 avg loss, 0.001000 rate, 6.919339 seconds, 80128 images, 11.863873 hours left
# Loaded: 0.522182 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1253: 1.219196, 1.897352 avg loss, 0.001000 rate, 6.833152 seconds, 80192 images, 11.871584 hours left
# Loaded: 2.181518 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1254: 2.116701, 1.919287 avg loss, 0.001000 rate, 6.936968 seconds, 80256 images, 11.849857 hours left
# Loaded: 2.965962 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1255: 2.066193, 1.933978 avg loss, 0.001000 rate, 6.997627 seconds, 80320 images, 11.851571 hours left
# Loaded: 0.000058 seconds
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1256: 1.089987, 1.849579 avg loss, 0.001000 rate, 6.973089 seconds, 80384 images, 11.864381 hours left
# Loaded: 4.962537 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1257: 2.900512, 1.954672 avg loss, 0.001000 rate, 7.086335 seconds, 80448 images, 11.837628 hours left
# Loaded: 3.085782 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1258: 2.235703, 1.982775 avg loss, 0.001000 rate, 6.890568 seconds, 80512 images, 11.877996 hours left
# Loaded: 0.259305 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1259: 1.446838, 1.929181 avg loss, 0.001000 rate, 6.870407 seconds, 80576 images, 11.890627 hours left
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
# Loaded: 2.927913 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1260: 2.142291, 1.950492 avg loss, 0.001000 rate, 7.016823 seconds, 80640 images, 11.865615 hours left
# Resizing, random_coef = 1.40
#
#  384 x 384
#  try to allocate additional workspace_size = 89.18 MB
#  CUDA allocate done!
# Loaded: 0.000065 seconds
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1261: 2.744703, 2.029913 avg loss, 0.001000 rate, 10.275659 seconds, 80704 images, 11.877898 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1262: 1.563403, 1.983262 avg loss, 0.001000 rate, 10.365025 seconds, 80768 images, 11.894388 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1263: 1.672904, 1.952226 avg loss, 0.001000 rate, 10.345097 seconds, 80832 images, 11.911860 hours left
# Loaded: 0.000076 seconds
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1264: 2.162316, 1.973235 avg loss, 0.001000 rate, 10.322366 seconds, 80896 images, 11.928866 hours left
# Loaded: 0.000108 seconds
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1265: 1.001683, 1.876080 avg loss, 0.001000 rate, 10.288995 seconds, 80960 images, 11.945375 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1266: 1.692492, 1.857721 avg loss, 0.001000 rate, 10.384632 seconds, 81024 images, 11.961252 hours left
# Loaded: 0.000054 seconds
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1267: 2.214904, 1.893440 avg loss, 0.001000 rate, 10.596409 seconds, 81088 images, 11.978198 hours left
# Loaded: 0.125421 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1268: 2.696691, 1.973765 avg loss, 0.001000 rate, 10.484158 seconds, 81152 images, 11.997731 hours left
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
# Loaded: 1.457452 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1269: 2.446695, 2.021058 avg loss, 0.001000 rate, 10.409053 seconds, 81216 images, 12.017211 hours left
# Loaded: 0.000061 seconds
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1270: 1.352643, 1.954216 avg loss, 0.001000 rate, 10.278946 seconds, 81280 images, 12.052984 hours left
# Resizing, random_coef = 1.40
#
#  256 x 256
#  try to allocate additional workspace_size = 37.75 MB
#  CUDA allocate done!
# Loaded: 3.021825 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1271: 2.060080, 1.964803 avg loss, 0.001000 rate, 4.877744 seconds, 81344 images, 12.067509 hours left
# Loaded: 5.539874 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1272: 2.285719, 1.996894 avg loss, 0.001000 rate, 4.814183 seconds, 81408 images, 12.050604 hours left
# Loaded: 7.217244 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1273: 2.877599, 2.084965 avg loss, 0.001000 rate, 4.792671 seconds, 81472 images, 12.066082 hours left
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
# Loaded: 1.889748 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1274: 1.347709, 2.011239 avg loss, 0.001000 rate, 4.691908 seconds, 81536 images, 12.103118 hours left
# Loaded: 3.268013 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1275: 1.977516, 2.007867 avg loss, 0.001000 rate, 4.748739 seconds, 81600 images, 12.068489 hours left
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
# Loaded: 3.977967 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1276: 2.327591, 2.039839 avg loss, 0.001000 rate, 4.929970 seconds, 81664 images, 12.053025 hours left
# Loaded: 3.801147 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1277: 1.908768, 2.026732 avg loss, 0.001000 rate, 4.740872 seconds, 81728 images, 12.049387 hours left
# Loaded: 5.694636 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1278: 2.863723, 2.110431 avg loss, 0.001000 rate, 4.797623 seconds, 81792 images, 12.040960 hours left
# Loaded: 3.053857 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1279: 1.742284, 2.073617 avg loss, 0.001000 rate, 4.748493 seconds, 81856 images, 12.058174 hours left
# Loaded: 1.094619 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1280: 1.101749, 1.976430 avg loss, 0.001000 rate, 4.643241 seconds, 81920 images, 12.039912 hours left
# Resizing, random_coef = 1.40
#
#  256 x 256
#  try to allocate additional workspace_size = 37.75 MB
#  CUDA allocate done!
# Loaded: 6.128034 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1281: 1.494380, 1.928225 avg loss, 0.001000 rate, 4.796246 seconds, 81984 images, 11.994742 hours left
# Loaded: 4.329568 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1282: 1.908547, 1.926257 avg loss, 0.001000 rate, 4.725539 seconds, 82048 images, 12.017994 hours left
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
# Loaded: 5.179164 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1283: 2.423380, 1.975969 avg loss, 0.001000 rate, 4.817021 seconds, 82112 images, 12.016487 hours left
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
# Loaded: 7.034325 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1284: 2.675509, 2.045923 avg loss, 0.001000 rate, 4.793486 seconds, 82176 images, 12.027300 hours left
# Loaded: 1.097537 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1285: 1.061028, 1.947434 avg loss, 0.001000 rate, 4.707059 seconds, 82240 images, 12.061972 hours left
# Loaded: 6.336236 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1286: 2.002724, 1.952963 avg loss, 0.001000 rate, 4.901324 seconds, 82304 images, 12.017376 hours left
# Loaded: 5.747761 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1287: 2.114056, 1.969072 avg loss, 0.001000 rate, 4.783542 seconds, 82368 images, 12.044353 hours left
# Loaded: 4.918212 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1288: 2.093529, 1.981518 avg loss, 0.001000 rate, 4.757600 seconds, 82432 images, 12.061782 hours left
# Loaded: 5.128294 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1289: 1.980636, 1.981430 avg loss, 0.001000 rate, 4.749384 seconds, 82496 images, 12.067810 hours left
# Loaded: 4.609070 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1290: 2.473195, 2.030606 avg loss, 0.001000 rate, 4.840394 seconds, 82560 images, 12.076392 hours left
# Resizing, random_coef = 1.40
#
#  352 x 352
#  try to allocate additional workspace_size = 26.79 MB
#  CUDA allocate done!
# Loaded: 0.000087 seconds
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1291: 1.509609, 1.978506 avg loss, 0.001000 rate, 8.468764 seconds, 82624 images, 12.079259 hours left
# Loaded: 0.778463 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1292: 1.653123, 1.945968 avg loss, 0.001000 rate, 8.576549 seconds, 82688 images, 12.069244 hours left
# Loaded: 2.347211 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1293: 2.124365, 1.963808 avg loss, 0.001000 rate, 8.562412 seconds, 82752 images, 12.070895 hours left
# Loaded: 3.980148 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1294: 2.687101, 2.036137 avg loss, 0.001000 rate, 8.669038 seconds, 82816 images, 12.092829 hours left
# Loaded: 2.093851 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1295: 2.332156, 2.065739 avg loss, 0.001000 rate, 8.470433 seconds, 82880 images, 12.137254 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1296: 1.362057, 1.995371 avg loss, 0.001000 rate, 8.481196 seconds, 82944 images, 12.153951 hours left
# Loaded: 0.919981 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1297: 1.752848, 1.971118 avg loss, 0.001000 rate, 8.574120 seconds, 83008 images, 12.143234 hours left
# Loaded: 4.406415 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1298: 2.601948, 2.034201 avg loss, 0.001000 rate, 8.404162 seconds, 83072 images, 12.145831 hours left
# Loaded: 0.000069 seconds
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1299: 1.063483, 1.937130 avg loss, 0.001000 rate, 8.287374 seconds, 83136 images, 12.191694 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 1300 iterations)
#  Last accuracy mAP@0.5 = 28.84 %, best = 68.87 %
#  1300: 1.054525, 1.848869 avg loss, 0.001000 rate, 8.403714 seconds, 83200 images, 12.177997 hours left
# Resizing to initial size: 256 x 256  try to allocate additional workspace_size = 37.75 MB
#  CUDA allocate done!
#
#  calculation mAP (mean average precision)...
# 60
#  detections_count = 409, unique_truth_count = 116
# class_id = 0, name = dueDate, ap = 62.11%   	 (TP = 14, FP = 13)
# class_id = 1, name = invDate, ap = 68.83%   	 (TP = 38, FP = 29)
# class_id = 2, name = invNo, ap = 74.74%   	 (TP = 43, FP = 16)
#
#  for conf_thresh = 0.25, precision = 0.62, recall = 0.82, F1-score = 0.71
#  for conf_thresh = 0.25, TP = 95, FP = 58, FN = 21, average IoU = 40.42 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.685610, or 68.56 %
# Total Detection Time: 10 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset
#
#  mean_average_precision (mAP@0.5) = 0.685610
# Saving weights to build/darknet/x64/backup//yolo-obj_last.weights
# Resizing, random_coef = 1.40
#
#  256 x 256
#  try to allocate additional workspace_size = 37.75 MB
#  CUDA allocate done!
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
# Loaded: 7.199940 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1301: 1.670707, 1.831053 avg loss, 0.001000 rate, 4.812404 seconds, 83264 images, 12.325446 hours left
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
# Loaded: 5.196877 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1302: 2.400637, 1.888011 avg loss, 0.001000 rate, 4.748284 seconds, 83328 images, 12.358986 hours left
# Loaded: 3.494354 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1303: 1.879557, 1.887166 avg loss, 0.001000 rate, 4.752015 seconds, 83392 images, 12.365181 hours left
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
# Loaded: 3.345861 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1304: 1.878277, 1.886277 avg loss, 0.001000 rate, 4.783949 seconds, 83456 images, 12.349122 hours left
# Loaded: 7.041657 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1305: 2.739759, 1.971625 avg loss, 0.001000 rate, 4.798462 seconds, 83520 images, 12.331680 hours left
# Loaded: 3.127652 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1306: 2.030399, 1.977503 avg loss, 0.001000 rate, 4.737549 seconds, 83584 images, 12.362778 hours left
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
# Loaded: 3.584447 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1307: 1.611948, 1.940947 avg loss, 0.001000 rate, 4.718807 seconds, 83648 images, 12.341704 hours left
# Loaded: 4.102177 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1308: 1.704457, 1.917298 avg loss, 0.001000 rate, 4.726617 seconds, 83712 images, 12.326529 hours left
# Loaded: 3.791108 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1309: 2.139769, 1.939545 avg loss, 0.001000 rate, 4.802969 seconds, 83776 images, 12.318333 hours left
# Loaded: 8.390423 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1310: 3.317028, 2.077293 avg loss, 0.001000 rate, 4.834233 seconds, 83840 images, 12.307135 hours left
# Resizing, random_coef = 1.40
#
#  384 x 384
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#  try to allocate additional workspace_size = 89.18 MB
#  CUDA allocate done!
# Loaded: 0.208245 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1311: 2.400465, 2.109611 avg loss, 0.001000 rate, 10.569976 seconds, 83904 images, 12.356352 hours left
# Loaded: 0.000035 seconds
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1312: 2.253656, 2.124015 avg loss, 0.001000 rate, 10.622158 seconds, 83968 images, 12.373175 hours left
# Loaded: 0.524167 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1313: 2.740096, 2.185623 avg loss, 0.001000 rate, 10.745367 seconds, 84032 images, 12.387768 hours left
# Loaded: 4.147348 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1314: 2.812972, 2.248358 avg loss, 0.001000 rate, 10.648077 seconds, 84096 images, 12.410614 hours left
# Loaded: 0.000063 seconds
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1315: 1.934122, 2.216934 avg loss, 0.001000 rate, 10.543540 seconds, 84160 images, 12.479095 hours left
# Loaded: 1.300313 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1316: 2.359169, 2.231158 avg loss, 0.001000 rate, 10.481776 seconds, 84224 images, 12.491518 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1317: 1.444265, 2.152469 avg loss, 0.001000 rate, 10.384991 seconds, 84288 images, 12.519901 hours left
# Loaded: 0.000055 seconds
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1318: 1.889839, 2.126206 avg loss, 0.001000 rate, 10.643309 seconds, 84352 images, 12.529794 hours left
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
# Loaded: 2.953388 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1319: 2.450464, 2.158632 avg loss, 0.001000 rate, 10.618097 seconds, 84416 images, 12.542919 hours left
# Loaded: 0.000043 seconds
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1320: 1.719035, 2.114672 avg loss, 0.001000 rate, 10.321414 seconds, 84480 images, 12.593957 hours left
# Resizing, random_coef = 1.40
#
#  224 x 224
#  try to allocate additional workspace_size = 28.90 MB
#  CUDA allocate done!
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
# Loaded: 4.836494 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1321: 2.404700, 2.143675 avg loss, 0.001000 rate, 3.779394 seconds, 84544 images, 12.602197 hours left
# Loaded: 4.846065 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1322: 1.884481, 2.117755 avg loss, 0.001000 rate, 3.716737 seconds, 84608 images, 12.588158 hours left
# Loaded: 1.822447 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1323: 1.111906, 2.017170 avg loss, 0.001000 rate, 3.731805 seconds, 84672 images, 12.573545 hours left
# Loaded: 6.232997 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1324: 2.068804, 2.022334 avg loss, 0.001000 rate, 3.886259 seconds, 84736 images, 12.519969 hours left
# Loaded: 3.113588 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1325: 1.780002, 1.998101 avg loss, 0.001000 rate, 3.761857 seconds, 84800 images, 12.526207 hours left
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
# Loaded: 4.331740 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1326: 1.922212, 1.990512 avg loss, 0.001000 rate, 3.744654 seconds, 84864 images, 12.490231 hours left
# Loaded: 4.648021 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1327: 1.804169, 1.971877 avg loss, 0.001000 rate, 3.773215 seconds, 84928 images, 12.470187 hours left
# Loaded: 6.747120 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1328: 2.791789, 2.053869 avg loss, 0.001000 rate, 3.806427 seconds, 84992 images, 12.454798 hours left
# Loaded: 2.941821 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1329: 1.404397, 1.988921 avg loss, 0.001000 rate, 3.751071 seconds, 85056 images, 12.467212 hours left
# Loaded: 7.842287 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1330: 3.457825, 2.135812 avg loss, 0.001000 rate, 3.948191 seconds, 85120 images, 12.429380 hours left
# Resizing, random_coef = 1.40
#
#  256 x 256
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#  try to allocate additional workspace_size = 37.75 MB
#  CUDA allocate done!
# Loaded: 3.791344 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1331: 2.645564, 2.186787 avg loss, 0.001000 rate, 4.760368 seconds, 85184 images, 12.458035 hours left
# Loaded: 1.418645 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1332: 1.109729, 2.079081 avg loss, 0.001000 rate, 4.647046 seconds, 85248 images, 12.444366 hours left
# Loaded: 4.280452 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1333: 2.513337, 2.122507 avg loss, 0.001000 rate, 4.803823 seconds, 85312 images, 12.398575 hours left
# Loaded: 4.231501 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1334: 1.986233, 2.108879 avg loss, 0.001000 rate, 4.889551 seconds, 85376 images, 12.392357 hours left
# Loaded: 3.474494 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1335: 1.957314, 2.093723 avg loss, 0.001000 rate, 4.740183 seconds, 85440 images, 12.386653 hours left
# Loaded: 8.206267 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1336: 2.617164, 2.146067 avg loss, 0.001000 rate, 4.829513 seconds, 85504 images, 12.369235 hours left
# Loaded: 4.823639 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1337: 2.236381, 2.155098 avg loss, 0.001000 rate, 4.766022 seconds, 85568 images, 12.414428 hours left
# Loaded: 1.827654 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1338: 1.455994, 2.085188 avg loss, 0.001000 rate, 4.697400 seconds, 85632 images, 12.414497 hours left
# Loaded: 5.674368 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1339: 2.202755, 2.096945 avg loss, 0.001000 rate, 4.831659 seconds, 85696 images, 12.374852 hours left
# Loaded: 2.433280 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1340: 1.358429, 2.023093 avg loss, 0.001000 rate, 4.766715 seconds, 85760 images, 12.387127 hours left
# Resizing, random_coef = 1.40
#
#  224 x 224
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#  try to allocate additional workspace_size = 28.90 MB
#  CUDA allocate done!
# Loaded: 5.750561 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1341: 1.509266, 1.971710 avg loss, 0.001000 rate, 3.757754 seconds, 85824 images, 12.356456 hours left
# Loaded: 3.426643 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1342: 1.501629, 1.924702 avg loss, 0.001000 rate, 3.723110 seconds, 85888 images, 12.355946 hours left
# Loaded: 1.406842 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1343: 1.183527, 1.850585 avg loss, 0.001000 rate, 3.742080 seconds, 85952 images, 12.324896 hours left
# Loaded: 5.117612 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1344: 1.815190, 1.847045 avg loss, 0.001000 rate, 3.800466 seconds, 86016 images, 12.268255 hours left
# Loaded: 5.296052 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1345: 2.342986, 1.896639 avg loss, 0.001000 rate, 3.890489 seconds, 86080 images, 12.260913 hours left
# Loaded: 6.092514 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1346: 2.166371, 1.923612 avg loss, 0.001000 rate, 3.811791 seconds, 86144 images, 12.257091 hours left
# Loaded: 6.820158 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1347: 3.288097, 2.060061 avg loss, 0.001000 rate, 3.875505 seconds, 86208 images, 12.262561 hours left
# Loaded: 5.635178 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1348: 1.738694, 2.027924 avg loss, 0.001000 rate, 3.746506 seconds, 86272 images, 12.278177 hours left
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
# Loaded: 4.220087 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1349: 2.129507, 2.038083 avg loss, 0.001000 rate, 3.769029 seconds, 86336 images, 12.276628 hours left
# Loaded: 4.119454 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1350: 1.751597, 2.009434 avg loss, 0.001000 rate, 3.867281 seconds, 86400 images, 12.257077 hours left
# Resizing, random_coef = 1.40
#
#  320 x 320
#  try to allocate additional workspace_size = 29.49 MB
#  CUDA allocate done!
# Loaded: 0.627492 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1351: 1.418563, 1.950347 avg loss, 0.001000 rate, 6.802198 seconds, 86464 images, 12.237668 hours left
# Loaded: 0.440637 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1352: 1.465812, 1.901893 avg loss, 0.001000 rate, 6.908881 seconds, 86528 images, 12.211238 hours left
# Loaded: 2.188221 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1353: 1.542884, 1.865992 avg loss, 0.001000 rate, 6.863501 seconds, 86592 images, 12.184016 hours left
# Loaded: 2.485908 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1354: 1.919497, 1.871343 avg loss, 0.001000 rate, 7.000651 seconds, 86656 images, 12.179019 hours left
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
# Loaded: 4.483208 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1355: 2.059026, 1.890111 avg loss, 0.001000 rate, 7.110132 seconds, 86720 images, 12.179658 hours left
# Loaded: 2.212213 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1356: 1.929345, 1.894035 avg loss, 0.001000 rate, 6.922714 seconds, 86784 images, 12.207448 hours left
# Loaded: 2.365196 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1357: 1.506959, 1.855327 avg loss, 0.001000 rate, 6.915670 seconds, 86848 images, 12.203215 hours left
# Loaded: 2.480270 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1358: 1.567546, 1.826549 avg loss, 0.001000 rate, 6.994671 seconds, 86912 images, 12.200880 hours left
# Loaded: 3.594465 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1359: 2.032411, 1.847135 avg loss, 0.001000 rate, 6.962824 seconds, 86976 images, 12.201046 hours left
# Loaded: 0.150020 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1360: 1.535223, 1.815944 avg loss, 0.001000 rate, 6.843483 seconds, 87040 images, 12.215137 hours left
# Resizing, random_coef = 1.40
#
#  320 x 320
#  try to allocate additional workspace_size = 29.49 MB
#  CUDA allocate done!
# Loaded: 4.659785 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1361: 0.909166, 1.725266 avg loss, 0.001000 rate, 6.975784 seconds, 87104 images, 12.183124 hours left
# Loaded: 5.244785 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1362: 2.552247, 1.807964 avg loss, 0.001000 rate, 7.067846 seconds, 87168 images, 12.211230 hours left
# Loaded: 3.606944 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1363: 1.910288, 1.818197 avg loss, 0.001000 rate, 7.052042 seconds, 87232 images, 12.247746 hours left
# Loaded: 3.775518 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1364: 2.585069, 1.894884 avg loss, 0.001000 rate, 6.988518 seconds, 87296 images, 12.262562 hours left
# Loaded: 1.997085 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1365: 1.781357, 1.883531 avg loss, 0.001000 rate, 6.890556 seconds, 87360 images, 12.278554 hours left
# Loaded: 1.002845 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1366: 1.653590, 1.860537 avg loss, 0.001000 rate, 6.908124 seconds, 87424 images, 12.270197 hours left
# Loaded: 2.293537 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1367: 1.940123, 1.868496 avg loss, 0.001000 rate, 6.951789 seconds, 87488 images, 12.249327 hours left
# Loaded: 4.468927 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1368: 2.058399, 1.887486 avg loss, 0.001000 rate, 7.079032 seconds, 87552 images, 12.245816 hours left
# Loaded: 1.974541 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1369: 1.710953, 1.869833 avg loss, 0.001000 rate, 6.937566 seconds, 87616 images, 12.271942 hours left
# Loaded: 1.058708 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1370: 1.241773, 1.807027 avg loss, 0.001000 rate, 6.950897 seconds, 87680 images, 12.263867 hours left
# Resizing, random_coef = 1.40
#
#  256 x 256
#  try to allocate additional workspace_size = 37.75 MB
#  CUDA allocate done!
# Loaded: 7.102411 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1371: 1.706474, 1.796972 avg loss, 0.001000 rate, 4.749729 seconds, 87744 images, 12.244242 hours left
# Loaded: 5.644818 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1372: 2.262730, 1.843547 avg loss, 0.001000 rate, 4.960222 seconds, 87808 images, 12.274198 hours left
# Loaded: 2.572664 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1373: 1.301333, 1.789326 avg loss, 0.001000 rate, 4.691697 seconds, 87872 images, 12.287790 hours left
# Loaded: 4.478147 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
#  1374: 1.608711, 1.771264 avg loss, 0.001000 rate, 4.742531 seconds, 87936 images, 12.258280 hours left
# Loaded: 2.410388 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1400 iterations)
#  Last accuracy mAP@0.5 = 68.56 %, best = 68.87 %
# ...
#  2014: 1.238651, 1.415977 avg loss, 0.001000 rate, 10.318709 seconds, 128896 images, 10.326043 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2015: 1.070523, 1.381432 avg loss, 0.001000 rate, 10.317387 seconds, 128960 images, 10.337034 hours left
# Loaded: 0.000066 seconds
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2016: 1.601735, 1.403462 avg loss, 0.001000 rate, 10.534026 seconds, 129024 images, 10.347872 hours left
# Loaded: 0.493979 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2017: 1.731239, 1.436240 avg loss, 0.001000 rate, 10.346247 seconds, 129088 images, 10.360971 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2018: 1.377903, 1.430406 avg loss, 0.001000 rate, 10.416564 seconds, 129152 images, 10.377297 hours left
# Loaded: 0.000033 seconds
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2019: 1.226270, 1.409993 avg loss, 0.001000 rate, 10.391301 seconds, 129216 images, 10.388743 hours left
# Loaded: 0.000055 seconds
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2020: 1.639254, 1.432919 avg loss, 0.001000 rate, 10.467977 seconds, 129280 images, 10.399767 hours left
# Resizing, random_coef = 1.40
#
#  224 x 224
#  try to allocate additional workspace_size = 28.90 MB
#  CUDA allocate done!
# Loaded: 2.656271 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2021: 1.861691, 1.475796 avg loss, 0.001000 rate, 3.839423 seconds, 129344 images, 10.411499 hours left
# Loaded: 2.782165 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2022: 1.268231, 1.455039 avg loss, 0.001000 rate, 3.786047 seconds, 129408 images, 10.379180 hours left
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
# Loaded: 2.054481 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2023: 1.182722, 1.427808 avg loss, 0.001000 rate, 3.717621 seconds, 129472 images, 10.347967 hours left
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
# Loaded: 2.318629 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2024: 1.185555, 1.403582 avg loss, 0.001000 rate, 3.699850 seconds, 129536 images, 10.308253 hours left
# Loaded: 0.910685 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2025: 0.727833, 1.336007 avg loss, 0.001000 rate, 3.712998 seconds, 129600 images, 10.271642 hours left
# Loaded: 2.780219 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2026: 1.173906, 1.319797 avg loss, 0.001000 rate, 3.724465 seconds, 129664 images, 10.219979 hours left
# Loaded: 3.211494 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2027: 1.636432, 1.351461 avg loss, 0.001000 rate, 3.782036 seconds, 129728 images, 10.189583 hours left
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
# Loaded: 5.221873 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2028: 1.998429, 1.416158 avg loss, 0.001000 rate, 3.831280 seconds, 129792 images, 10.164869 hours left
# Loaded: 2.015144 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2029: 1.282661, 1.402808 avg loss, 0.001000 rate, 3.736866 seconds, 129856 images, 10.163107 hours left
# Loaded: 1.348707 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2030: 0.878576, 1.350385 avg loss, 0.001000 rate, 3.715242 seconds, 129920 images, 10.124924 hours left
# Resizing, random_coef = 1.40
#
#  256 x 256
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#  try to allocate additional workspace_size = 37.75 MB
#  CUDA allocate done!
# Loaded: 2.096187 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2031: 1.613103, 1.376657 avg loss, 0.001000 rate, 4.702187 seconds, 129984 images, 10.079519 hours left
# Loaded: 6.091609 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2032: 2.197868, 1.458778 avg loss, 0.001000 rate, 4.770314 seconds, 130048 images, 10.053676 hours left
# Loaded: 4.306971 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2033: 1.718214, 1.484721 avg loss, 0.001000 rate, 4.830926 seconds, 130112 images, 10.072862 hours left
# Loaded: 0.389098 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2034: 0.710359, 1.407285 avg loss, 0.001000 rate, 4.641316 seconds, 130176 images, 10.072828 hours left
# Loaded: 4.522265 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2035: 1.932187, 1.459775 avg loss, 0.001000 rate, 4.736225 seconds, 130240 images, 10.027519 hours left
# Loaded: 2.828963 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2036: 1.749988, 1.488797 avg loss, 0.001000 rate, 4.692220 seconds, 130304 images, 10.029216 hours left
# Loaded: 2.075193 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2037: 1.312980, 1.471215 avg loss, 0.001000 rate, 4.669946 seconds, 130368 images, 10.011740 hours left
# Loaded: 1.376418 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2038: 1.002093, 1.424303 avg loss, 0.001000 rate, 4.712210 seconds, 130432 images, 9.985876 hours left
# Loaded: 0.458826 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2039: 0.845541, 1.366427 avg loss, 0.001000 rate, 4.618263 seconds, 130496 images, 9.953026 hours left
# Loaded: 1.828773 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2040: 1.196373, 1.349421 avg loss, 0.001000 rate, 4.668438 seconds, 130560 images, 9.909358 hours left
# Resizing, random_coef = 1.40
#
#  320 x 320
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#  try to allocate additional workspace_size = 29.49 MB
#  CUDA allocate done!
# Loaded: 1.855838 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2041: 1.389839, 1.353463 avg loss, 0.001000 rate, 7.015354 seconds, 130624 images, 9.881734 hours left
# Loaded: 0.048862 seconds
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2042: 1.204288, 1.338546 avg loss, 0.001000 rate, 6.872803 seconds, 130688 images, 9.880475 hours left
# Loaded: 3.435659 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2043: 1.906427, 1.395334 avg loss, 0.001000 rate, 6.977254 seconds, 130752 images, 9.857771 hours left
# Loaded: 3.553950 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2044: 2.282537, 1.484054 avg loss, 0.001000 rate, 6.919162 seconds, 130816 images, 9.873648 hours left
# Loaded: 0.810682 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2045: 1.423996, 1.478048 avg loss, 0.001000 rate, 6.897119 seconds, 130880 images, 9.890000 hours left
# Loaded: 0.063081 seconds
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2046: 0.977315, 1.427975 avg loss, 0.001000 rate, 6.834040 seconds, 130944 images, 9.875779 hours left
# Loaded: 0.000037 seconds
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2047: 0.709213, 1.356099 avg loss, 0.001000 rate, 6.934111 seconds, 131008 images, 9.852775 hours left
# Loaded: 2.580902 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2048: 2.046852, 1.425174 avg loss, 0.001000 rate, 6.844609 seconds, 131072 images, 9.830388 hours left
# Loaded: 1.354521 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2049: 1.280641, 1.410721 avg loss, 0.001000 rate, 6.931155 seconds, 131136 images, 9.835556 hours left
# Loaded: 1.395460 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2050: 1.731282, 1.442777 avg loss, 0.001000 rate, 6.956517 seconds, 131200 images, 9.828136 hours left
# Resizing, random_coef = 1.40
#
#  352 x 352
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#  try to allocate additional workspace_size = 26.79 MB
#  CUDA allocate done!
# Loaded: 0.000054 seconds
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2051: 1.115263, 1.410026 avg loss, 0.001000 rate, 8.409904 seconds, 131264 images, 9.821494 hours left
# Loaded: 1.834183 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2052: 1.744799, 1.443503 avg loss, 0.001000 rate, 8.433205 seconds, 131328 images, 9.815532 hours left
# Loaded: 0.880664 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2053: 1.759838, 1.475136 avg loss, 0.001000 rate, 8.451977 seconds, 131392 images, 9.829976 hours left
# Loaded: 0.277617 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2054: 1.139226, 1.441545 avg loss, 0.001000 rate, 8.337665 seconds, 131456 images, 9.833998 hours left
# Loaded: 0.575248 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2055: 1.382393, 1.435630 avg loss, 0.001000 rate, 8.379881 seconds, 131520 images, 9.830092 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2056: 0.995254, 1.391593 avg loss, 0.001000 rate, 8.509125 seconds, 131584 images, 9.829924 hours left
# Loaded: 0.263429 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2057: 1.378327, 1.390266 avg loss, 0.001000 rate, 8.417551 seconds, 131648 images, 9.824848 hours left
# Loaded: 2.141886 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2058: 1.496125, 1.400852 avg loss, 0.001000 rate, 8.501041 seconds, 131712 images, 9.821681 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2059: 0.821472, 1.342914 avg loss, 0.001000 rate, 8.400714 seconds, 131776 images, 9.840004 hours left
# Loaded: 0.128772 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2060: 1.193026, 1.327925 avg loss, 0.001000 rate, 8.382705 seconds, 131840 images, 9.833569 hours left
# Resizing, random_coef = 1.40
#
#  224 x 224
#  try to allocate additional workspace_size = 28.90 MB
#  CUDA allocate done!
# Loaded: 3.151952 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2061: 1.373047, 1.332437 avg loss, 0.001000 rate, 3.833946 seconds, 131904 images, 9.828387 hours left
# Loaded: 5.282281 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2062: 2.094701, 1.408664 avg loss, 0.001000 rate, 3.733418 seconds, 131968 images, 9.806541 hours left
# Loaded: 4.421605 seconds - performance bottleneck on CPU or Disk HDD/SSD
# Failed to infer label file name (check image extension is supported): /content/darknet/build/darknet/x64/data/obj/usableinvoiceberry_indesign_invoice_template_lime_on_ice.jpg.pagespeed.ce.gaEfGwdBT_.jpg
#
#  (next mAP calculation at 2100 iterations)
#  Last accuracy mAP@0.5 = 92.39 %, best = 93.67 %
#  2063: 1.583390, 1.426136 avg loss, 0.001000 rate, 3.767267 seconds, 132032 images, 9.807097 hours left

# %%
COLAB_MODEL = '/content/darknet/build/darknet/x64/backup/yolo-5000.weights'
DRIVE_MODEL = '/content/gdrive/My Drive/OCR Object Detection/yolo-obj_5000.weights'

shutil.copy(COLAB_MODEL, DRIVE_MODEL)

# %% [markdown]
# - Open [URL](http://ip-address:8090) to display mAP

# %%
# To train further
# !./darknet detector train build/darknet/x64/data/obj.data build/darknet/x64/cfg/yolo-obj.cfg build/darknet/x64/backup/yolo-5000.weights -dont_show -map

# %%
COLAB_MODEL = '/content/darknet/build/darknet/x64/backup/yolo-5000.weights'
DRIVE_MODEL = '/content/gdrive/My Drive/OCR Object Detection/yolo-obj_10000.weights'

shutil.copy(COLAB_MODEL, DRIVE_MODEL)

# %% [markdown]
# ## Detection

# %% [markdown]
# ### Test on Video
# - To perform object detection on a video
# - Saved as `result.avi`

# %%
# ./darknet detector demo build/darknet/x64/data/obj.data build/darknet/x64/cfg/yolo-obj.cfg build/darknet/x64/backup/yolo-obj_1000.weights build/darknet/x64/data/peralta_holt_mumps.mp4 -out_filename result.avi -ext_output -dont_show

# %% [markdown]
# ### Test on Image
# - To perform object detection on an image
# - Saved as `test.jpg`

# %%
# !./darknet detector test build/darknet/x64/data/obj.data build/darknet/x64/cfg/yolo-obj.cfg build/darknet/x64/backup/yolo-obj_1000.weights test.jpg -dont_show
# !./darknet detector test build/darknet/x64/data/obj.data build/darknet/x64/cfg/yolo-obj.cfg build/darknet/x64/backup/yolo-obj_final.weights build/darknet/x64/data/obj/Invoice_1.jpg -dont_show

# %%
def predictImage(imageDir):
  os.system("cd /content/darknet && ./darknet detector test build/darknet/x64/data/obj.data build/darknet/x64/cfg/yolo-obj.cfg build/darknet/x64/backup/yolo-obj_final.weights {}".format(imageDir))
  image = cv2.imread("/content/darknet/predictions.jpg")
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)
  fig = plt.gcf()
  fig.set_size_inches(15, 8)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %%
predictImage("/content/darknet/build/darknet/x64/data/obj/Invoice_1.jpg")

# %% [markdown]
# ### Test on Real-time Feed
# - To perform object detection on a real-time video

# %%
# !./darknet detector demo build/darknet/x64/data/obj.data build/darknet/x64/cfg/yolo-obj.cfg build/darknet/x64/backup/yolo-obj_1000.weights -c 0

# %% [markdown]
# ### Test on Image using Weights from GDrive

# %%
from google.colab import drive
from google.colab import files
import shutil

DRIVE_WEIGHTS = '/content/gdrive/My Drive/HLA/Models/YOLOv4/Exp1/yolov4-obj_best.weights'
COLAB_WEIGHTS = '/content/darknet/build/darknet/x64/backup/yolov4-obj_best.weights'

# drive.mount('/content/gdrive')
shutil.copy(DRIVE_WEIGHTS, COLAB_WEIGHTS)
print('Download completed!')

# %%
% cd '/content/darknet'

# !./darknet detector test build/darknet/x64/data/obj.data build/darknet/x64/cfg/yolov4-obj.cfg build/darknet/x64/backup/yolov4-obj_best.weights build/darknet/x64/data/obj/Invoice_118_118.jpg -dont_show

# %%
image = cv2.imread("/content/darknet/predictions.jpg")
height, width = image.shape[:2]
resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)
# resized_image = cv2.resize(image,(width, height), interpolation = cv2.INTER_CUBIC)
fig = plt.gcf()
fig.set_size_inches(30, 16)
plt.axis("off")
plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
import matplotlib.patches as patches

for xml_file in [f for f in os.listdir(DATASET_DIR) if f.endswith(".xml")][:1]:
  xml_file = "Invoice_118_118.xml"

  tree = ET.parse(os.path.join(DATASET_DIR, xml_file))
  root = tree.getroot()

  obj_list = []

  image_file = xml_file.replace(".xml", ".jpg")
  print('/content/darknet/build/darknet/x64/data/obj/' + image_file)

  image = cv2.imread("/content/darknet/build/darknet/x64/data/obj/" + image_file)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(width, height), interpolation = cv2.INTER_CUBIC)
  fig,ax = plt.subplots(1)
  fig.set_size_inches(30, 16)
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))

  for elem in root:

    if elem.tag == 'size':
      for subelem in elem:
        if subelem.tag == 'width':
          img_width = subelem.text
        if subelem.tag == 'height':
          img_height = subelem.text

    if elem.tag == 'object':
      obj_name = None
      obj_classId = None
      for subelem in elem:
        if subelem.tag == 'name':
          # ONLY IF TRAINING SPECIFIC CLASSES
          # if subelem.text == 'totalPrice' or subelem.text == 'unitPrice':
            obj_name = subelem.text
            obj_classId = obj_class.index(obj_name)
        if subelem.tag == 'bndbox':
          for subsubelem in subelem:
            if subsubelem.tag == 'xmin':
              xmin = float("{:.6f}".format(int(subsubelem.text)/int(img_width)))
            if subsubelem.tag == 'xmax':
              xmax = float("{:.6f}".format(int(subsubelem.text)/int(img_width)))
            if subsubelem.tag == 'ymin':
              ymin = float("{:.6f}".format(int(subsubelem.text)/int(img_height)))
            if subsubelem.tag == 'ymax':
              ymax = float("{:.6f}".format(int(subsubelem.text)/int(img_height)))
      
      if obj_classId is not None:
        obj_elem = "{} {} {} {} {}".format(obj_classId, xmin, ymin, xmax, ymax)
        obj_list.append(obj_elem)

    print("{} {} {} {} {}".format(obj_name, xmin*width, ymin*height, xmax*width, ymax*height))

    # Create a Rectangle patch
    rect = patches.Rectangle((xmin*width,ymin*height),(xmax-xmin)*width,(ymax-ymin)*height,linewidth=1,edgecolor='r',facecolor='none')

    # Add the patch to the Axes
    ax.add_patch(rect)

    plt.text(xmin*width,ymin*height,obj_name,fontsize=12)
  
  text_file = xml_file.replace(".xml", ".txt")

  plt.show()

# print('/content/darknet/build/darknet/x64/data/obj/' + image_file)
# print("{} {} {} {} {}".format(obj_name, xmin*width, ymin*height, xmax*width, ymax*height))

# image = cv2.imread("/content/darknet/build/darknet/x64/data/obj/" + image_file)
# height, width = image.shape[:2]
# resized_image = cv2.resize(image,(width, height), interpolation = cv2.INTER_CUBIC)
# # fig = plt.gcf()
# fig,ax = plt.subplots(1)
# fig.set_size_inches(30, 16)
# # plt.axis("off")
# plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))

# # Create a Rectangle patch
# rect = patches.Rectangle((xmin*width,ymin*height),(xmax-xmin)*width,(ymax-ymin)*height,linewidth=1,edgecolor='r',facecolor='none')

# # Add the patch to the Axes
# ax.add_patch(rect)

# plt.show()

  # print(text_file)
  # print(obj_list)
  # print('\n'.join(obj_list))

  # f=open(os.path.join(DATASET_DIR, text_file),'w')
  # s1='\n'.join(obj_list)
  # f.write(s1)
  # f.close()

# %% [markdown]
# #### To calculate anchors:

# %%
# !./darknet detector calc_anchors build/darknet/x64/data/obj.data -num_of_clusters 9 -width 256 -height 256

# %% [markdown]
# #### To check accuracy mAP@IoU=50:

# %%
# !./darknet detector map build/darknet/x64/data/obj.data build/darknet/x64/cfg/yolov4-obj.cfg build/darknet/x64/backup/yolov4-obj_best.weights

# %% [markdown]
# #### To check accuracy mAP@IoU=75:

# %%
# !./darknet detector map build/darknet/x64/data/obj.data build/darknet/x64/cfg/yolov4-obj.cfg build/darknet/x64/backup/yolov4-obj_best.weights -iou_thresh 0.75

# %% [markdown]
# - To process a list of images data/train.txt and save results of detection to result.json file use:
#
# `darknet.exe detector test cfg/coco.data cfg/yolov4.cfg yolov4.weights -ext_output -dont_show -out result.json < data/train.txt`
#
# - To process a list of images data/train.txt and save results of detection to result.txt use:
#
# `darknet.exe detector test cfg/coco.data cfg/yolov4.cfg yolov4.weights -dont_show -ext_output < data/train.txt > result.txt`
